# %% [markdown]
# # SLU2 - Subsetting data in Pandas: Learning notebook

# %% [markdown]
# In this notebook we will cover the following topics:
#     - Setting pandas Dataframe index
#     - Selecting columns (brackets and dot notation)
#     - Selecting rows (loc and iloc)
#     - Chain indexing (not good) vs Multi-axis indexing (good)
#     - Masks
#     - Where
#     - Subsetting on conditions
#     - Basic math operations: adding columns and rows
#     - Removing columns and rows

# %% [markdown]
# First, we import pandas, like we learned in the previous unit. It will be the only think that we will need for this learning unit as well.

# %%
import pandas as pd

# This is an option to preview less rows in the notebook's cells' outputs
pd.options.display.max_rows = 10

# %% [markdown]
# Now, we read the data that we'll use in this unit from the file __airbnb_input.csv__, which is located in the __data/__ directory.
#
# For this, we'll use function __read_csv( )__, which was alreay shown in the previous unit.
# We want to use column __room_id__ as the DataFrame index, and for that we use the argument __index_col__.

# %%
# Read the data in file airbnb_input.csv into a pandas DataFrame and use column room_id as the DataFrame index.
df = pd.read_csv('data/airbnb_input.csv', index_col='room_id')

# Preview the first rows of the DataFrame.
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %% [markdown]
# ## Sorting the index

# %% [markdown]
# With the [sort_index](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_index.html) function, we can sort the DataFrame along the index.
#
# For instance, our DataFrame df was already sorted along the index, but we can resort it from bigger to smaller rooms ids, using the __ascending=False__ parameter.

# %%
# Original df
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
# df with the index sorted from bigger to smaller room_id
df.sort_index(ascending=False)
# Out:
#             host_id        room_type       neighborhood  reviews  \
# room_id
# 19400722   28219108  Entire home/apt            Areeiro        0
# 19397373   97139334  Entire home/apt        São Vicente        0
# 19396300    6115933  Entire home/apt      Santo António        0
# 19393935    5376796  Entire home/apt  Santa Maria Maior        0
# 19388006  135915593  Entire home/apt        São Vicente        0
# ...             ...              ...                ...      ...
# 29396        126415  Entire home/apt  Santa Maria Maior      132
# 29248        125768  Entire home/apt  Santa Maria Maior      225
# 25659        107347  Entire home/apt  Santa Maria Maior       63
# 17031         66015  Entire home/apt           Alvalade        0
# 6499          14455  Entire home/apt              Belém        8
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 19400722                   0.0             5       3.0   75.0
# 19397373                   0.0             4       1.0   56.0
# 19396300                   0.0             6       4.0  138.0
# 19393935                   0.0             3       1.0   50.0
# 19388006                   0.0             6       3.0  415.0
# ...                        ...           ...       ...    ...
# 29396                      5.0             4       1.0   67.0
# 29248                      4.5             4       1.0   58.0
# 25659                      5.0             3       1.0   69.0
# 17031                      0.0             2       1.0   46.0
# 6499                       5.0             2       1.0   57.0
#
# [13232 rows x 8 columns]

# %% [markdown]
# ## Resetting the index

# %% [markdown]
# We can reset the index of a DataFrame with function [reset_index](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html).
# This will convert the index into a range from 0 to the length of the DataFrame minus 1.
#
# Regarding the old index, we can either keep it by adding it as a column in the DataFrame (__drop=False__, this is the default behaviour) or reset it completely (__drop=True__).

# %%
# Resetting the index and keeping it as a new column room_id
df.reset_index()
# Out:
#         room_id    host_id        room_type       neighborhood  reviews  \
# 0          6499      14455  Entire home/apt              Belém        8
# 1         17031      66015  Entire home/apt           Alvalade        0
# 2         25659     107347  Entire home/apt  Santa Maria Maior       63
# 3         29248     125768  Entire home/apt  Santa Maria Maior      225
# 4         29396     126415  Entire home/apt  Santa Maria Maior      132
# ...         ...        ...              ...                ...      ...
# 13227  19388006  135915593  Entire home/apt        São Vicente        0
# 13228  19393935    5376796  Entire home/apt  Santa Maria Maior        0
# 13229  19396300    6115933  Entire home/apt      Santo António        0
# 13230  19397373   97139334  Entire home/apt        São Vicente        0
# 13231  19400722   28219108  Entire home/apt            Areeiro        0
#
#        overall_satisfaction  accommodates  bedrooms  price
# 0                       5.0             2       1.0   57.0
# 1                       0.0             2       1.0   46.0
# 2                       5.0             3       1.0   69.0
# 3                       4.5             4       1.0   58.0
# 4                       5.0             4       1.0   67.0
# ...                     ...           ...       ...    ...
# 13227                   0.0             6       3.0  415.0
# 13228                   0.0             3       1.0   50.0
# 13229                   0.0             6       4.0  138.0
# 13230                   0.0             4       1.0   56.0
# 13231                   0.0             5       3.0   75.0
#
# [13232 rows x 9 columns]

# %%
# Resetting the index and dropping it -> no new column is added
df.reset_index(drop=True)
# Out:
#          host_id        room_type       neighborhood  reviews  \
# 0          14455  Entire home/apt              Belém        8
# 1          66015  Entire home/apt           Alvalade        0
# 2         107347  Entire home/apt  Santa Maria Maior       63
# 3         125768  Entire home/apt  Santa Maria Maior      225
# 4         126415  Entire home/apt  Santa Maria Maior      132
# ...          ...              ...                ...      ...
# 13227  135915593  Entire home/apt        São Vicente        0
# 13228    5376796  Entire home/apt  Santa Maria Maior        0
# 13229    6115933  Entire home/apt      Santo António        0
# 13230   97139334  Entire home/apt        São Vicente        0
# 13231   28219108  Entire home/apt            Areeiro        0
#
#        overall_satisfaction  accommodates  bedrooms  price
# 0                       5.0             2       1.0   57.0
# 1                       0.0             2       1.0   46.0
# 2                       5.0             3       1.0   69.0
# 3                       4.5             4       1.0   58.0
# 4                       5.0             4       1.0   67.0
# ...                     ...           ...       ...    ...
# 13227                   0.0             6       3.0  415.0
# 13228                   0.0             3       1.0   50.0
# 13229                   0.0             6       4.0  138.0
# 13230                   0.0             4       1.0   56.0
# 13231                   0.0             5       3.0   75.0
#
# [13232 rows x 8 columns]

# %% [markdown]
# ## Setting the index

# %% [markdown]
# With function [set_index](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html), we can set a new index for our DataFrame.
#
# The old index is dropped.
#
# In this function, the __drop=True__ parameter deletes the column to be used as the new index, which is the default behaviour, and __drop=False__ keeps the column unchanged.

# %%
# Setting column neighborhood as the new index
# The neighborhood column is dropped from the DataFrame, this is the default behaviour
df.set_index('neighborhood', drop=True)
# Out:
#                      host_id        room_type  reviews  overall_satisfaction  \
# neighborhood
# Belém                  14455  Entire home/apt        8                   5.0
# Alvalade               66015  Entire home/apt        0                   0.0
# Santa Maria Maior     107347  Entire home/apt       63                   5.0
# Santa Maria Maior     125768  Entire home/apt      225                   4.5
# Santa Maria Maior     126415  Entire home/apt      132                   5.0
# ...                      ...              ...      ...                   ...
# São Vicente        135915593  Entire home/apt        0                   0.0
# Santa Maria Maior    5376796  Entire home/apt        0                   0.0
# Santo António        6115933  Entire home/apt        0                   0.0
# São Vicente         97139334  Entire home/apt        0                   0.0
# Areeiro             28219108  Entire home/apt        0                   0.0
#
#                    accommodates  bedrooms  price
# neighborhood
# Belém                         2       1.0   57.0
# Alvalade                      2       1.0   46.0
# Santa Maria Maior             3       1.0   69.0
# Santa Maria Maior             4       1.0   58.0
# Santa Maria Maior             4       1.0   67.0
# ...                         ...       ...    ...
# São Vicente                   6       3.0  415.0
# Santa Maria Maior             3       1.0   50.0
# Santo António                 6       4.0  138.0
# São Vicente                   4       1.0   56.0
# Areeiro                       5       3.0   75.0
#
# [13232 rows x 7 columns]

# %% [markdown]
# ## Selecting columns

# %% [markdown]
# ### Selecting columns by name - dot notation

# %% [markdown]
# Using __dot notation__, you can select a column from a DataFrame, obtaining a Series with the column values.
#
# This is how you can select the room_type column using dot notation:

# %%
df.room_type
# Out:
# room_id
# 6499        Entire home/apt
# 17031       Entire home/apt
# 25659       Entire home/apt
# 29248       Entire home/apt
# 29396       Entire home/apt
#                  ...
# 19388006    Entire home/apt
# 19393935    Entire home/apt
# 19396300    Entire home/apt
# 19397373    Entire home/apt
# 19400722    Entire home/apt
# Name: room_type, Length: 13232, dtype: object

# %% [markdown]
# ### Selecting columns by name - brackets notation

# %% [markdown]
# Using __brackets__, you can select one or more columns from the DataFrame.
#
# This is how you can select the room_type column using brackets. Note that the output is a Series:

# %%
df['room_type']
# Out:
# room_id
# 6499        Entire home/apt
# 17031       Entire home/apt
# 25659       Entire home/apt
# 29248       Entire home/apt
# 29396       Entire home/apt
#                  ...
# 19388006    Entire home/apt
# 19393935    Entire home/apt
# 19396300    Entire home/apt
# 19397373    Entire home/apt
# 19400722    Entire home/apt
# Name: room_type, Length: 13232, dtype: object

# %% [markdown]
# This is how you can select the room_type and neighborhood columns using brackets. Note that the output is a DataFrame:

# %%
df[['room_type', 'neighborhood']]
# Out:
#                 room_type       neighborhood
# room_id
# 6499      Entire home/apt              Belém
# 17031     Entire home/apt           Alvalade
# 25659     Entire home/apt  Santa Maria Maior
# 29248     Entire home/apt  Santa Maria Maior
# 29396     Entire home/apt  Santa Maria Maior
# ...                   ...                ...
# 19388006  Entire home/apt        São Vicente
# 19393935  Entire home/apt  Santa Maria Maior
# 19396300  Entire home/apt      Santo António
# 19397373  Entire home/apt        São Vicente
# 19400722  Entire home/apt            Areeiro
#
# [13232 rows x 2 columns]

# %% [markdown]
# ## Selecting rows

# %% [markdown]
# ### Selecting rows by index position - iloc
#
# With function [iloc](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html) you can select specific rows from a DataFrame.
#
# In order to specify the rows you want to select you can use the row position (integer starting from 0), a list, or an array slice.

# %% [markdown]
# This is how you can select the first row (remember that Python starts indexing with a 0). Note that the output is a Series:

# %%
df.iloc[0]
# Out:
# host_id                           14455
# room_type               Entire home/apt
# neighborhood                      Belém
# reviews                               8
# overall_satisfaction                  5
# accommodates                          2
# bedrooms                              1
# price                                57
# Name: 6499, dtype: object

# %% [markdown]
# This is how you select rows 0, 2, 4 and 6. Note that the output is a DataFrame:

# %%
df.iloc[[0, 2, 4, 6]]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29396     126415  Entire home/apt  Santa Maria Maior      132
# 29872     128698  Entire home/apt          Alcântara       25
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 25659                     5.0             3       1.0   69.0
# 29396                     5.0             4       1.0   67.0
# 29872                     5.0             2       1.0   75.0

# %% [markdown]
# This is how you select the first 3 rows:

# %%
df.iloc[:3]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0

# %% [markdown]
# We can pick __slices__ using the slice notation below:
#
# __$start:stop:step$__

# %%
df.iloc[1:10:2,:]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 17031      66015  Entire home/apt           Alvalade        0
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29720     128075  Entire home/apt            Estrela       14
# 29891     128792  Entire home/apt       Misericórdia       28
# 33312     144398  Entire home/apt       Misericórdia       24
#
#          overall_satisfaction  accommodates  bedrooms   price
# room_id
# 17031                     0.0             2       1.0    46.0
# 29248                     4.5             4       1.0    58.0
# 29720                     5.0            16       9.0  1154.0
# 29891                     5.0             3       1.0    49.0
# 33312                     4.5             4       1.0    66.0

# %% [markdown]
# ### Selecting rows by index name - loc
#
# With function [loc](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) you can select specific rows from a DataFrame, like with iloc.
#
# The difference here is that you specify the rows to select using the rows' indexes instead of the rows' positions in the DataFrame.

# %% [markdown]
# This is how you select room 29396:

# %%
df.loc[29396]
# Out:
# host_id                            126415
# room_type                 Entire home/apt
# neighborhood            Santa Maria Maior
# reviews                               132
# overall_satisfaction                    5
# accommodates                            4
# bedrooms                                1
# price                                  67
# Name: 29396, dtype: object

# %% [markdown]
# Note that if you search for an index that doesn't exist, you'll get a KeyError:

# %%
df.loc[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 100
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-3e0a0618caa1> in <module>
# ----> 1 df.loc[100]
#
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~/.Envs/batch4-slu02/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 100

# %% [markdown]
# We can also pass an array with multiple indexes just as we did for the the iloc function.

# %%
df.loc[[29396,17031]]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 29396     126415  Entire home/apt  Santa Maria Maior      132
# 17031      66015  Entire home/apt           Alvalade        0
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 29396                     5.0             4       1.0   67.0
# 17031                     0.0             2       1.0   46.0

# %% [markdown]
# We can also apply the slice operation using the loc function. It is important to sort the index before doing this operation.

# %%
df.loc[50000:70000,:]
# Out:
#          host_id        room_type      neighborhood  reviews  \
# room_id
# 50108     229376  Entire home/apt           Estrela       33
# 55116     259744     Private room    Avenidas Novas        1
# 56906     270457  Entire home/apt       São Vicente       86
# 57850     276092  Entire home/apt           Estrela       52
# 59227     184400  Entire home/apt      Misericórdia       25
# 65553     320407  Entire home/apt  Campo de Ourique      102
# 65878     322145  Entire home/apt      Misericórdia       51
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 50108                     4.5             4       1.0   69.0
# 55116                     0.0             2       2.0   68.0
# 56906                     4.5             3       1.0   52.0
# 57850                     4.5             3       2.0   70.0
# 59227                     4.5             7       3.0  138.0
# 65553                     4.5             2       1.0   58.0
# 65878                     5.0             4       1.0   76.0

# %% [markdown]
# One cool thing about the slice notation is that we can even use it with an index that is not integer. For example if our index is a string we can get a slice based on the alphabetic order of the index. Lets set the _neighborhood_ column as index and select all the rows whose _neighborhood_ is between 'Alvalade' and 'Belém'

# %%
df.set_index('neighborhood').sort_index().loc['Alvalade':'Belém',:]
# Out:
#                host_id        room_type  reviews  overall_satisfaction  \
# neighborhood
# Alvalade      31062136  Entire home/apt        8                   5.0
# Alvalade       2381723  Entire home/apt      116                   5.0
# Alvalade       8104036  Entire home/apt        0                   0.0
# Alvalade      11440809     Private room        0                   0.0
# Alvalade      62222594     Private room        0                   0.0
# ...                ...              ...      ...                   ...
# Belém          8048828  Entire home/apt      122                   5.0
# Belém         21277737  Entire home/apt        0                   0.0
# Belém          3168004  Entire home/apt       13                   4.5
# Belém          4132746     Private room       49                   4.5
# Belém          2341627  Entire home/apt       64                   4.5
#
#               accommodates  bedrooms  price
# neighborhood
# Alvalade                 8       3.0   83.0
# Alvalade                 4       2.0   52.0
# Alvalade                 2       1.0   64.0
# Alvalade                 2       1.0   40.0
# Alvalade                 2       1.0   52.0
# ...                    ...       ...    ...
# Belém                    4       1.0   58.0
# Belém                    4       2.0  230.0
# Belém                    3       2.0   46.0
# Belém                    3       1.0   22.0
# Belém                    4       1.0   67.0
#
# [3101 rows x 7 columns]

# %% [markdown]
# ## Multi-axis indexing

# %% [markdown]
# One nice thing about loc and iloc is that we can select columns and rows at the same time.
#
# Let's use the iloc to select based on the position of the rows and columns to pick the last five rows and the first 3 columns.

# %%
df.iloc[-5:,:3]
# Out:
#             host_id        room_type       neighborhood
# room_id
# 19388006  135915593  Entire home/apt        São Vicente
# 19393935    5376796  Entire home/apt  Santa Maria Maior
# 19396300    6115933  Entire home/apt      Santo António
# 19397373   97139334  Entire home/apt        São Vicente
# 19400722   28219108  Entire home/apt            Areeiro

# %% [markdown]
# Let's now use the loc to select based on the names of the rows and columns to pick the _neighborhood_ and _price_ of the rooms 29396 and 17031.

# %%
df.loc[[29396,17031],['neighborhood','price']]
# Out:
#               neighborhood  price
# room_id
# 29396    Santa Maria Maior   67.0
# 17031             Alvalade   46.0

# %% [markdown]
# ## A performance remark!
#
# ### Chain indexing vs Multi-axis indexing

# %% [markdown]
# Imagine you are asked to select the neighborhood of room 17031.
#
# When we want to select a specific value in a DataFrame, given the row and the column, we might be tempted to do the following:

# %%
# %%time
# This command is used to count the time that the code in this cell took to run

df['neighborhood'][17031]
# Out:
# CPU times: user 218 µs, sys: 6 µs, total: 224 µs
# Wall time: 229 µs
# 'Alvalade'

# %% [markdown]
# However, as you can see, this is a faster solution:

# %%
# %%time
df.loc[17031, 'neighborhood']
# Out:
# CPU times: user 73 µs, sys: 1 µs, total: 74 µs
# Wall time: 79.2 µs
# 'Alvalade'

# %% [markdown]
# But why?
#
# When we select a row or column in a DataFrame using brackets, the Python bellow Pandas is calling the \__getitem\__ method to return the requested data.
#
# Well, when we chain two sets of brackets, as in the first example, we are calling the \__getitem\__ method twice! This is called __chain indexing__, and __should be avoided__!
#
# On the other hand, when we use loc to select a value given a row and column at the same time, Python is only calling the \__getitem\__ method once. This is called __multi-axis indexing__, and should be used.

# %% [markdown]
# ## Masks

# %% [markdown]
# The [mask](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mask.html) function can be used to "hide" the rows that verify a certain condition.
#
# The rows where the condition holds will have the values replaced by NaN:

# %%
df.mask(df.overall_satisfaction == 5.0)
# Out:
#               host_id        room_type       neighborhood  reviews  \
# room_id
# 6499              NaN              NaN                NaN      NaN
# 17031         66015.0  Entire home/apt           Alvalade      0.0
# 25659             NaN              NaN                NaN      NaN
# 29248        125768.0  Entire home/apt  Santa Maria Maior    225.0
# 29396             NaN              NaN                NaN      NaN
# ...               ...              ...                ...      ...
# 19388006  135915593.0  Entire home/apt        São Vicente      0.0
# 19393935    5376796.0  Entire home/apt  Santa Maria Maior      0.0
# 19396300    6115933.0  Entire home/apt      Santo António      0.0
# 19397373   97139334.0  Entire home/apt        São Vicente      0.0
# 19400722   28219108.0  Entire home/apt            Areeiro      0.0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                       NaN           NaN       NaN    NaN
# 17031                      0.0           2.0       1.0   46.0
# 25659                      NaN           NaN       NaN    NaN
# 29248                      4.5           4.0       1.0   58.0
# 29396                      NaN           NaN       NaN    NaN
# ...                        ...           ...       ...    ...
# 19388006                   0.0           6.0       3.0  415.0
# 19393935                   0.0           3.0       1.0   50.0
# 19396300                   0.0           6.0       4.0  138.0
# 19397373                   0.0           4.0       1.0   56.0
# 19400722                   0.0           5.0       3.0   75.0
#
# [13232 rows x 8 columns]

# %% [markdown]
# ## Where

# %% [markdown]
# And the [where](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.where.html) function can be used to hide the rows that __don't__ verify a certain condition.
#
# The rows where the condition doesn't hold will have the values replaced by NaN:

# %%
df.where(df.overall_satisfaction == 5.0)
# Out:
#            host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455.0  Entire home/apt              Belém      8.0
# 17031          NaN              NaN                NaN      NaN
# 25659     107347.0  Entire home/apt  Santa Maria Maior     63.0
# 29248          NaN              NaN                NaN      NaN
# 29396     126415.0  Entire home/apt  Santa Maria Maior    132.0
# ...            ...              ...                ...      ...
# 19388006       NaN              NaN                NaN      NaN
# 19393935       NaN              NaN                NaN      NaN
# 19396300       NaN              NaN                NaN      NaN
# 19397373       NaN              NaN                NaN      NaN
# 19400722       NaN              NaN                NaN      NaN
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                       5.0           2.0       1.0   57.0
# 17031                      NaN           NaN       NaN    NaN
# 25659                      5.0           3.0       1.0   69.0
# 29248                      NaN           NaN       NaN    NaN
# 29396                      5.0           4.0       1.0   67.0
# ...                        ...           ...       ...    ...
# 19388006                   NaN           NaN       NaN    NaN
# 19393935                   NaN           NaN       NaN    NaN
# 19396300                   NaN           NaN       NaN    NaN
# 19397373                   NaN           NaN       NaN    NaN
# 19400722                   NaN           NaN       NaN    NaN
#
# [13232 rows x 8 columns]

# %% [markdown]
# Basically __mask__ and __where__ do the opposite of each other!

# %% [markdown]
# ## Subsetting data on conditions

# %% [markdown]
# Using brackets notation, we can use conditions to subset data from the DataFrame.
#
# By doing this, we get a DataFrame that (most likelly) has a different shape from the initial one, i.e, it's only a subset of it's rows.
#
# Note that this is different from what we saw in the mask/filter functions: these functions don't change the DataFame shape, instead, they just replace the values that we don't want with NaNs.

# %% [markdown]
# Here we're subsetting the DataFrame to get all the rooms in the Alvalade neighborhood.
#
# Note the DataFrame shape!

# %%
df[df.neighborhood == 'Alvalade']
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 17031         66015  Entire home/apt     Alvalade        0
# 72807        378525     Private room     Alvalade        1
# 108058       557442     Private room     Alvalade       24
# 143882       697596  Entire home/apt     Alvalade        0
# 172014       820718     Private room     Alvalade       77
# ...             ...              ...          ...      ...
# 19206346  131826194  Entire home/apt     Alvalade        0
# 19225159   84062304     Private room     Alvalade        0
# 19227195  134599148  Entire home/apt     Alvalade        0
# 19266319   15462808  Entire home/apt     Alvalade        0
# 19271004   48058268     Private room     Alvalade        0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 17031                      0.0             2       1.0   46.0
# 72807                      0.0             1       1.0   29.0
# 108058                     5.0             1       1.0   27.0
# 143882                     0.0             3       2.0  577.0
# 172014                     4.5             4       1.0   45.0
# ...                        ...           ...       ...    ...
# 19206346                   0.0             5       2.0   87.0
# 19225159                   0.0             2       1.0   54.0
# 19227195                   0.0             4       2.0   56.0
# 19266319                   0.0             2       1.0   52.0
# 19271004                   0.0             2       1.0   44.0
#
# [253 rows x 8 columns]

# %% [markdown]
# As another example, we're selecting the rooms in Alvalade, that have more than 10 reviews.
#
# Note the parenthesis around each condition, they're required!

# %%
df[(df.neighborhood == 'Alvalade') & (df.reviews > 10)]
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 108058       557442     Private room     Alvalade       24
# 172014       820718     Private room     Alvalade       77
# 172248       507901     Private room     Alvalade       38
# 216881      1119812  Entire home/apt     Alvalade       22
# 333919       507901     Private room     Alvalade       48
# ...             ...              ...          ...      ...
# 15044690   18671578  Entire home/apt     Alvalade       33
# 15786593  102115202  Entire home/apt     Alvalade       22
# 15839689   16844987  Entire home/apt     Alvalade       24
# 16690259   63598544  Entire home/apt     Alvalade       16
# 17221766  108559367     Private room     Alvalade       24
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 108058                     5.0             1       1.0   27.0
# 172014                     4.5             4       1.0   45.0
# 172248                     4.5             2       1.0   29.0
# 216881                     4.5             6       2.0   74.0
# 333919                     4.0             3       1.0   40.0
# ...                        ...           ...       ...    ...
# 15044690                   5.0             3       1.0   52.0
# 15786593                   5.0             5       2.0   57.0
# 15839689                   5.0             4       2.0   58.0
# 16690259                   5.0             2       1.0   58.0
# 17221766                   5.0             1       1.0   23.0
#
# [89 rows x 8 columns]

# %% [markdown]
# ## Basic Math Operations: Adding Rows & Columns

# %% [markdown]
# ### Adding a row
#
# We can use the __loc__ indexing operation to add a new row in a dataframe with a specific index. If dataframe already has any row with that index name then this will replace the contents of that row.

# %%
# Add new room to our dataframe with roomid=737800
df.loc[737800] = [123456,'Private room','Entrecampos',82,4.5,2,1,29.0]

# Show our new room
df.loc[737800]
# Out:
# host_id                       123456
# room_type               Private room
# neighborhood             Entrecampos
# reviews                           82
# overall_satisfaction             4.5
# accommodates                       2
# bedrooms                           1
# price                             29
# Name: 737800, dtype: object

# %% [markdown]
# We can use __iloc__ to replace the row at a given index position:

# %%
df.iloc[-1] = [56787,'Private room','Avenidas Novas',82,4.5,2,1,29.0]

# Show our new room
df.tail()
# Out:
#            host_id        room_type       neighborhood  reviews  \
# room_id
# 19393935   5376796  Entire home/apt  Santa Maria Maior        0
# 19396300   6115933  Entire home/apt      Santo António        0
# 19397373  97139334  Entire home/apt        São Vicente        0
# 19400722  28219108  Entire home/apt            Areeiro        0
# 737800       56787     Private room     Avenidas Novas       82
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 19393935                   0.0             3       1.0   50.0
# 19396300                   0.0             6       4.0  138.0
# 19397373                   0.0             4       1.0   56.0
# 19400722                   0.0             5       3.0   75.0
# 737800                     4.5             2       1.0   29.0

# %% [markdown]
# ### Adding a column

# %% [markdown]
# We can add a column to a daframe using the same notations that we used to select them, i.e., dot notation, brackets notation, or loc operator.

# %%
# Creates a new column in the DataFrame (price_per_week), where each row is equal to the price * 7
df['price_per_week'] = df.price * 7
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price  price_per_week
# room_id
# 6499                      5.0             2       1.0   57.0           399.0
# 17031                     0.0             2       1.0   46.0           322.0
# 25659                     5.0             3       1.0   69.0           483.0
# 29248                     4.5             4       1.0   58.0           406.0
# 29396                     5.0             4       1.0   67.0           469.0

# %%
# Creates a new column in the DataFrame (price_per_week), where each row is equal to the price * 7
df.loc['price_per_week'] = df.price * 7
df.head()
# Out:
#           host_id        room_type       neighborhood  reviews  \
# room_id
# 6499      14455.0  Entire home/apt              Belém      8.0
# 17031     66015.0  Entire home/apt           Alvalade      0.0
# 25659    107347.0  Entire home/apt  Santa Maria Maior     63.0
# 29248    125768.0  Entire home/apt  Santa Maria Maior    225.0
# 29396    126415.0  Entire home/apt  Santa Maria Maior    132.0
#
#          overall_satisfaction  accommodates  bedrooms  price  price_per_week
# room_id
# 6499                      5.0           2.0       1.0   57.0           399.0
# 17031                     0.0           2.0       1.0   46.0           322.0
# 25659                     5.0           3.0       1.0   69.0           483.0
# 29248                     4.5           4.0       1.0   58.0           406.0
# 29396                     5.0           4.0       1.0   67.0           469.0

# %% [markdown]
# There is also a cool function called [assign](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.assign.html). This function returns a new dataframe with all the columns plus the one that we creating.

# %%
# Creates new columns in the DataFrame (people_per_bedroom, price_per_month), 
# where each row is equal to the value of the accommodates column divided by the bedrooms column
df = df.assign(people_per_bedroom = df['accommodates']/df['bedrooms'],
          price_per_month = df['price'] * 31) 
df.head()
# Out:
#           host_id        room_type       neighborhood  reviews  \
# room_id
# 6499      14455.0  Entire home/apt              Belém      8.0
# 17031     66015.0  Entire home/apt           Alvalade      0.0
# 25659    107347.0  Entire home/apt  Santa Maria Maior     63.0
# 29248    125768.0  Entire home/apt  Santa Maria Maior    225.0
# 29396    126415.0  Entire home/apt  Santa Maria Maior    132.0
#
#          overall_satisfaction  accommodates  bedrooms  price  price_per_week  \
# room_id
# 6499                      5.0           2.0       1.0   57.0           399.0
# 17031                     0.0           2.0       1.0   46.0           322.0
# 25659                     5.0           3.0       1.0   69.0           483.0
# 29248                     4.5           4.0       1.0   58.0           406.0
# 29396                     5.0           4.0       1.0   67.0           469.0
#
#          people_per_bedroom  price_per_month
# room_id
# 6499                    2.0           1767.0
# 17031                   2.0           1426.0
# 25659                   3.0           2139.0
# 29248                   4.0           1798.0
# 29396                   4.0           2077.0

# %% [markdown]
# ## Removing Rows & Columns

# %% [markdown]
# In order to drop rows and columns from a DataFrame, we can use function [drop](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html).
#
# In order to drop a row, we do the following:

# %%
# This drops the row with index 17031. This is the same than doing drop(17031,axis=0)
df.drop(labels=17031)
# Out:
#                    host_id        room_type       neighborhood  reviews  \
# room_id
# 6499               14455.0  Entire home/apt              Belém      8.0
# 25659             107347.0  Entire home/apt  Santa Maria Maior     63.0
# 29248             125768.0  Entire home/apt  Santa Maria Maior    225.0
# 29396             126415.0  Entire home/apt  Santa Maria Maior    132.0
# 29720             128075.0  Entire home/apt            Estrela     14.0
# ...                    ...              ...                ...      ...
# 19396300         6115933.0  Entire home/apt      Santo António      0.0
# 19397373        97139334.0  Entire home/apt        São Vicente      0.0
# 19400722        28219108.0  Entire home/apt            Areeiro      0.0
# 737800             56787.0     Private room     Avenidas Novas     82.0
# price_per_week         NaN              NaN                NaN      NaN
#
#                 overall_satisfaction  accommodates  bedrooms   price  \
# room_id
# 6499                             5.0           2.0       1.0    57.0
# 25659                            5.0           3.0       1.0    69.0
# 29248                            4.5           4.0       1.0    58.0
# 29396                            5.0           4.0       1.0    67.0
# 29720                            5.0          16.0       9.0  1154.0
# ...                              ...           ...       ...     ...
# 19396300                         0.0           6.0       4.0   138.0
# 19397373                         0.0           4.0       1.0    56.0
# 19400722                         0.0           5.0       3.0    75.0
# 737800                           4.5           2.0       1.0    29.0
# price_per_week                   NaN           NaN       NaN     NaN
#
#                 price_per_week  people_per_bedroom  price_per_month
# room_id
# 6499                     399.0            2.000000           1767.0
# 25659                    483.0            3.000000           2139.0
# 29248                    406.0            4.000000           1798.0
# 29396                    469.0            4.000000           2077.0
# 29720                   8078.0            1.777778          35774.0
# ...                        ...                 ...              ...
# 19396300                 966.0            1.500000           4278.0
# 19397373                 392.0            4.000000           1736.0
# 19400722                 525.0            1.666667           2325.0
# 737800                   203.0            2.000000            899.0
# price_per_week             NaN                 NaN              NaN
#
# [13233 rows x 11 columns]

# %% [markdown]
# In order to drop a column, we do the following:

# %%
# This drops column neighborhood. This is the same than doing drop('neighborhood',axis=1)
df.drop(columns='neighborhood')
# Out:
#                    host_id        room_type  reviews  overall_satisfaction  \
# room_id
# 6499               14455.0  Entire home/apt      8.0                   5.0
# 17031              66015.0  Entire home/apt      0.0                   0.0
# 25659             107347.0  Entire home/apt     63.0                   5.0
# 29248             125768.0  Entire home/apt    225.0                   4.5
# 29396             126415.0  Entire home/apt    132.0                   5.0
# ...                    ...              ...      ...                   ...
# 19396300         6115933.0  Entire home/apt      0.0                   0.0
# 19397373        97139334.0  Entire home/apt      0.0                   0.0
# 19400722        28219108.0  Entire home/apt      0.0                   0.0
# 737800             56787.0     Private room     82.0                   4.5
# price_per_week         NaN              NaN      NaN                   NaN
#
#                 accommodates  bedrooms  price  price_per_week  \
# room_id
# 6499                     2.0       1.0   57.0           399.0
# 17031                    2.0       1.0   46.0           322.0
# 25659                    3.0       1.0   69.0           483.0
# 29248                    4.0       1.0   58.0           406.0
# 29396                    4.0       1.0   67.0           469.0
# ...                      ...       ...    ...             ...
# 19396300                 6.0       4.0  138.0           966.0
# 19397373                 4.0       1.0   56.0           392.0
# 19400722                 5.0       3.0   75.0           525.0
# 737800                   2.0       1.0   29.0           203.0
# price_per_week           NaN       NaN    NaN             NaN
#
#                 people_per_bedroom  price_per_month
# room_id
# 6499                      2.000000           1767.0
# 17031                     2.000000           1426.0
# 25659                     3.000000           2139.0
# 29248                     4.000000           1798.0
# 29396                     4.000000           2077.0
# ...                            ...              ...
# 19396300                  1.500000           4278.0
# 19397373                  4.000000           1736.0
# 19400722                  1.666667           2325.0
# 737800                    2.000000            899.0
# price_per_week                 NaN              NaN
#
# [13234 rows x 10 columns]

# %% [markdown]
# If we want to drop multiple rows (or columns), we can use lists:

# %%
df.drop(labels=[6499, 17031])
# Out:
#                    host_id        room_type       neighborhood  reviews  \
# room_id
# 25659             107347.0  Entire home/apt  Santa Maria Maior     63.0
# 29248             125768.0  Entire home/apt  Santa Maria Maior    225.0
# 29396             126415.0  Entire home/apt  Santa Maria Maior    132.0
# 29720             128075.0  Entire home/apt            Estrela     14.0
# 29872             128698.0  Entire home/apt          Alcântara     25.0
# ...                    ...              ...                ...      ...
# 19396300         6115933.0  Entire home/apt      Santo António      0.0
# 19397373        97139334.0  Entire home/apt        São Vicente      0.0
# 19400722        28219108.0  Entire home/apt            Areeiro      0.0
# 737800             56787.0     Private room     Avenidas Novas     82.0
# price_per_week         NaN              NaN                NaN      NaN
#
#                 overall_satisfaction  accommodates  bedrooms   price  \
# room_id
# 25659                            5.0           3.0       1.0    69.0
# 29248                            4.5           4.0       1.0    58.0
# 29396                            5.0           4.0       1.0    67.0
# 29720                            5.0          16.0       9.0  1154.0
# 29872                            5.0           2.0       1.0    75.0
# ...                              ...           ...       ...     ...
# 19396300                         0.0           6.0       4.0   138.0
# 19397373                         0.0           4.0       1.0    56.0
# 19400722                         0.0           5.0       3.0    75.0
# 737800                           4.5           2.0       1.0    29.0
# price_per_week                   NaN           NaN       NaN     NaN
#
#                 price_per_week  people_per_bedroom  price_per_month
# room_id
# 25659                    483.0            3.000000           2139.0
# 29248                    406.0            4.000000           1798.0
# 29396                    469.0            4.000000           2077.0
# 29720                   8078.0            1.777778          35774.0
# 29872                    525.0            2.000000           2325.0
# ...                        ...                 ...              ...
# 19396300                 966.0            1.500000           4278.0
# 19397373                 392.0            4.000000           1736.0
# 19400722                 525.0            1.666667           2325.0
# 737800                   203.0            2.000000            899.0
# price_per_week             NaN                 NaN              NaN
#
# [13232 rows x 11 columns]
